# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = (
    f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
    + f'&fq={filter_query}&sort={sort}&fl={field_list}'
)

# %% [markdown]
# ### Access the New York Times API

# %%
reviews_list = []
for page in range(0, 20):
    page_query_url = f"{query_url}&page={page}"
    reviews = requests.get(page_query_url).json()
    
    
    # Add a one second interval between queries to stay within API query limits
    time.sleep(12)
    try:
        for review in reviews["response"]["docs"]:
            reviews_list.append(review)
        print(f"checkedpage {page}")
    except:
        print(f"no results found for page {page}") 
        break
# Out:
# checkedpage 0
# checkedpage 1
# checkedpage 2
# checkedpage 3
# checkedpage 4
# checkedpage 5
# checkedpage 6
# checkedpage 7
# checkedpage 8
# checkedpage 9
# checkedpage 10
# checkedpage 11
# checkedpage 12
# checkedpage 13
# checkedpage 14
# checkedpage 15
# checkedpage 16
# checkedpage 17
# checkedpage 18
# checkedpage 19

# %%
for review in reviews_list:
    print(review['snippet'])
# Out:
# A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.
# Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.
# Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.
# Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.
# A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone’s lives.
# A film adaptation of Taylor Jenkins Reid’s novel has potential for drama, but it stumbles on stock melodrama.
# There’s not much Lennon music heard in this doc about his affair with May Pang, and given how much Pang trashes his wife, Yoko Ono, it’s no surprise it was withheld.
# A mesmerizing Teyana Taylor stars in A.V. Rockwell’s feature directing debut, about motherhood and survival in a fast-changing city.
# This humdrum Netflix romantic comedy features Reese Witherspoon and Ashton Kutcher as longtime friends with possibly hidden feelings for each other.
# To combat the overdose crisis, a group that includes former and current users open a safe consumption site where shooting up does not have to mean death.
# This documentary from Ryan White rewinds, to powerful effect, on Pamela Anderson’s life and fame.
# In Matt Carter’s gay rugby film, sports and romance smash together like two players from opposing teams.
# In this intelligent melodrama by the director Aleem Khan, a British woman discovers her husband has been leading a double life.
# In this naturalistic drama from Spain, a family confronts the impending loss of its generations-old farm.
# A family archive provides intimate records of a love affair that began between two women imprisoned in the Ravensbrück concentration camp.
# The new Netflix adaptation of D.H. Lawrence’s once-controversial novel is both steamy and decorous.
# A young singer gets more than she bargained for when she accepts a job as a nanny for a billionaire’s children.
# Elegance Bratton’s autobiographical first feature is a lyrical, wrenching look at a young Marine’s journey through basic training.
# Luca Guadagnino’s latest stars Timothée Chalamet and Taylor Russell as young cannibals on the run.
# A schoolteacher, her police officer husband and his lover deny each other romantic satisfaction in this dismal melodrama.
# Thomas Mann’s beguiling performance drives this Emma Roberts vehicle, but the romantic comedy creaks under the weight of its coincidences.
# Set in Paris in the 1960s, the film tells the story of two irrepressible lovers, and their young son, whose tale turns tragic.
# This comedy is a daddy-issues movie with a queasy premise truly made for these times.
# Two former childhood friends rekindle their connection in this sweetly hopeful story of romantic longing.
# Katie Holmes writes, directs and stars in this minor-key rom-com set in 2020.
# A disillusioned college professor develops a relationship with a young Chinese woman, in a familiar and worn-out narrative.
# In this marriage drama, a young couple heads to the countryside to break out of a toxic cycle.
# The director Taika Waititi injects antic silliness, once again, into this Marvel franchise starring Chris Hemsworth, who swings a mighty hammer and flexes mightier muscles.
# In the latest film from Claire Denis, Juliette Binoche plays a Parisian radio journalist in a romantic quandary.
# Sara Dosa’s new documentary chronicles the lives and deaths of the French scientists Katia and Maurice Krafft.
# A mother’s final wish leads her daughter to retrace her Roman holiday in this lighthearted coming-of-age story.
# A new documentary about the gospel ensemble the Branchettes and its guiding light, Lena Mae Perry, is a plain-spoken tribute.
# Terence Davies’s latest film is a biography of Siegfried Sassoon, whose writing about World War I changed British literature.
# A rage-fueled rock singer on the run from the police meets and falls in love with a gullible young woman eager to escape her circumstances.
# This drama from Ximan Li teases time in telling the stories of three Chinese women living in a city that tempts promise but delivers frustration.
# A restless woman discovers herself in a seductive French romance that throws out the usual dusty script about women, desire and pleasure.
# The determinedly uplifting comedy follows a 50-year-old French filmmaker as she dates in Los Angeles.
# Former lovers reconnect, litigating the past and present, in this drama from Mari Walker.
# This documentary about the den mother of dancers at a Mexico City cabaret is vérité at its best.
# Ann Hui’s World War II-era film is lovely to look at but lacks emotional depth and resonance.
# An unhappy husband raises suspicions when his wife’s lovers begin to disappear.
# This documentary, directed by Amy Poehler and about the dynamic duo behind “I Love Lucy,” favors the good times over the difficult ones.
# Peter Dinklage wields pen and sword in a musical adaptation of the durable French romance.
# A teenage girl thinks that her dead boyfriend’s spirit is reaching out from the Great Beyond.
# Unbeknown to the author of an uninspired romance novel, the book takes a sharp turn into erotic territory in its Spanish-language release.
# In this electric liberation story from Chad, a mother struggles to protect her daughter’s future and finds both herself and a world of possibility.
# Iuli Gerbase’s first feature film reflects a funhouse-mirror image of our present lives.
# The actors Michael B. Jordan and Chanté Adams bring a compelling chemistry to the screen as opposites who fall for each other.
# Steven Spielberg rediscovers the breathing, troubling essence of a classic, building a bold and current screen musical with no pretense to perfection.
# This melodramatic documentary chronicles how Aulcie Perry, a basketball center from New Jersey, became a celebrity in Israel after he joined the Maccabi Tel Aviv team.
# The characters in this idle drama, directed by Eleanor Coppola, seem mostly content. That’s the problem.
# When a perennially single journalist travels across the country to meet her dream guy, she finds she’s been catfished.
# In Mia Hansen-Love’s new film, Vicky Krieps and Tim Roth play filmmakers on the rocks in the Baltic Sea.
# Drawn from the plotline of a Todd Snider song, the film follows a pool shark and an escort, taking twists that are both violent and silly.
# Jason Sudeikis plays a paroled felon who vows to give his dying lover the best year of her life.
# In this latest work by Kiyoshi Kurosawa, a Japanese couple’s relationship is shaped by the forces of churning nationalism that surround it.
# In the Disney+ concert film “Happier Than Ever: A Love Letter to Los Angeles,” the pop star Billie Eilish pays tribute to the star-struck hauntedness of that city.
# Sharon Horgan and James McAvoy play a battling couple trapped in lockdown in this theatrical pandemic drama.
# Adam Driver and Marion Cotillard are star-crossed lovers in this hallucinatory musical, written by Sparks and directed by Leos Carax.
# In this romantic comedy, a woman reeling from a failed engagement and a flailing career escapes to a glamorous island resort.
# An HBO documentary examines a music festival that went so far off the rails that it defined an era.
# Benoît Jacquot’s erotic costume drama envisions the Italian playboy as a weathered sad sack living in exile.
# Two childhood best friends reunite in this unfocused yet uplifting sports drama by the filmmaker Jan Philipp Weyl.
# This drama about a young single mother and a terminally ill daughter avoids sentimentalism but indulges heavily in dourness.
# Paula Beer and Franz Rogowski, who made an impression in 2019’s “Transit,” are reunited by the director Christian Petzold for this adaptation of a European myth.
# This small-town comedy from New Zealand looks at the romance between a country girl and a man accused of killing his family.
# A conservative father who could not accept his son’s sexuality is led on a contemplative tour of queer life in New York in this Bolivian film.
# Fiery physical contact keeps an expat couple together in Greece, and the sex scenes are enough for a half-dozen movies.
# After upending her life, a woman runs away with her longtime crush in this puzzling Japanese drama.
# This documentary chronicles eight years in the lives of a group of children who form a bond after discovering they were conceived by the same sperm donor.
# In this romantic drama from Jon Garcia, two men find love in prison, then try to make it work on the outside.
# In this keeps-you-guessing comedy, Joel McHale and Kerry Bishé play a couple married for 14 years whose mutual passion is undimmed, to the annoyance of their friends.
# Ava DuVernay’s 2008 documentary, now streaming on Netflix, is a personal love letter to a slice of Los Angeles’s 1990s hip-hop scene.
# This final installment of the Netflix rom-com trilogy is earnest, bright-eyed and without a hint of cynicism.
# The brother and sister filmmakers Sarah Sherman and Zachary Ray Sherman deliver romance, unadorned.
# This sci-fi romance imagines a world with widespread memory loss through the eyes of one couple.
# An older lesbian couple is met with unexpected devastation in this aching romantic drama by Filippo Meneghetti.
# Ukraine’s official Oscar entry, the movie depicts an all-too-convincing dystopia, with no fancy gadgets or cars.
# A neurosurgeon pursues the man of her dreams in this simmering portrait of obsession by the Hungarian filmmaker Lili Horvat.
# The filmmaker Patrick Liu keeps the focus on the two young men in this Taiwanese drama and blurs the rest.
# Tessa Thompson and Nnamdi Asomugha star in a swoony love story that wonderfully rethinks the classic Hollywood melodrama.
# Sometimes it’s enough to adore a pop star from afar, even if you aren’t an Arianator.
# This documentary looks at how a contemporary art museum in Western Massachusetts transformed a struggling small town.
# John Patrick Shanley adapts his play “Outside Mullingar” into a movie. (Don’t worry about the accents.)
# This Errol Morris documentary explores the relationship between the LSD guru and Joanna Harcourt-Smith, a woman who likened herself to Mata Hari.
# The rise and fall of the provocative rapper Tekashi69 is chronicled in this Hulu documentary.
# Kate Winslet’s fossil hunter and Saoirse Ronan’s convalescent embark on a forbidden seaside romance.
# The new sci-fi adventure from Michael Matthews lacks the self-seriousness of typical dystopian flicks but doesn’t completely lack depth.
# With the help of her father, the documentary filmmaker Kirsten Johnson made a surprising, endearing movie about his death.
# Rachael Leigh Cook stars in this rom-com about a lawyer and her charming new client who wants to sue a dating website for falsely promising love.
# A prickly professional dancer becomes a reluctant instructor for a preteen dance troupe in this formulaic dramedy.
# Eliza Scanlen plays a seriously ill high schooler who falls for the wrong guy who turns out to have the right stuff, after all.
# This Netflix documentary explores the unbroken Indian-American dominance of the U.S. national spelling bee, to less than winning results.
# This tender film explores the partnership between two women who lived, in public and to kin, as dear friends for six decades.
# A couple’s reception becomes a disaster (or does it?) in this comedy of multiple errors.
# This ensemble comedy treats class solidarity as the love that dare not speak its name.
# Annette Bening and Bill Nighy play a couple that has lost its way after 29 years of marriage.
# Elle Fanning and Justice Smith breathe life into a film about mental illness and the healing power of love.
# Issa Rae and a terrific Lakeith Stanfield play a New York couple whose romance sends them and the story into the past.
# A mysterious architect persuades an amnesiac that she’s his wife in this elusive romance set in the Sahara.
# Lesley Manville and Liam Neeson play a married couple facing a cancer diagnosis.
# The second installment in Netflix’s ’80s-style teen romance trilogy asks the question John Hughes left unanswered.
# This warm documentary uses one woman’s singular passion to fuel a tale of zoological discovery, blatant sexism and environmental alarm.
# Daniel Kaluuya and Jodie Turner-Smith star in Melina Matsoukas’s dreamy but intense outlaw romance.
# Adam Driver and Scarlett Johansson self-consciously uncouple in Noah Baumbach’s tender, stinging tale of divorce.
# This superficial take on the writing and initial staging of “Cyrano de Bergerac” is a whirlwind of soapy declarations and backstage chaos.
# Directed by James Franco and featuring James Franco, this film indulges in a distasteful brand of nostalgia.
# The prolific director Takashi Miike delivers an unusually satisfying Japanese genre romp.
# Toni Servillo plays the former Italian Prime Minister Silvio Berlusconi in Paolo Sorrentino’s extravagant portrait.
# It’s hard to find a reliable, talented, reasonably priced, eco-friendly contractor these days.
# Steve Coogan stars in this cumbersome political comedy.
# Anton Yelchin, who played Chekov in the J.J. Abrams-produced “Star Trek” films, assembled an eclectic filmography before his death at 27 in 2016.
# Kirill Serebrennikov’s gentle mood piece brings an underground music scene to vivid life.
# Blythe Danner and John Lithgow strain to elevate this twee late-life romance.
# The Japanese director Ryusuke Hamaguchi follows up his marathon “Happy Hour” with a story of love among young urbanites.
# Yara Shahidi and Charles Melton play teenagers falling in love on a hectic, sunny day in New York.
# The options are few and most of them involve risk or further deprivation for these French teenagers who face the world with little support.
# The improbably yet perfectly paired stars play old friends who unexpectedly find love in this charming (and a bit vulgar) romantic comedy.
# A ruthless empiricist searching for life beyond Earth learns a thing or two about life on the planet.
# Abhishek Varman’s maximalist melodrama delivers spectacle (some of it mind-numbing) but fails to tell a gripping story.
# The story of a romance between two Kenyan women was shown at Cannes after being banned in Kenya.
# Mary Kay Place is astonishing as a weary widow dealing with guilt, heartache and a diminishing circle of friends.
# Haley Lu Richardson and Cole Sprouse navigate the rules of attraction and of a hospital in this film about living with cystic fibrosis.
# In Jia Zhangke’s enthralling new feature, Zhao Tao and Liao Fan portray an underworld power couple at the mercy of time and fate.
# The Chilean writer-director Sebastián Lelio finds a perfect partner in Moore for this fantastic remake of his 2013 movie “Gloria.”
# In Khalik Allah’s poetic movie, the most prevalent perspective is not that of a documentarian, but of a filmmaker’s love.
# Something strange is going on in the Irish countryside, and it’s not just the giant roiling pit of dirt.
# The third in this franchise concerns the exigencies that poor Hiccup must face as the leader of Berk.
# This joyous documentary follows the Preservation Hall Jazz Band to Cuba for a celebration of musical history and common bonds.
# Dwayne Johnson helped produce this charming comedy about a family of professional wrestlers, their chops, drops and drama.
# Set in early 1990s Paris, Christophe Honoré’s new film presents us with a middle-aged, H.I.V.-stricken writer falling, wearily, for a bookish 20-something.
# The once-divided nature of Berlin isn’t given much consideration in this film, part of the Cities of Love series.
# Jemima Kirke and Lola Kirke play damaged siblings in this exasperatingly affected romantic drama from Emma Forrest.
# In post-World War II Poland, a singer and a piano player find each other, fall in love and soon end up on opposite sides of history.
# The couple in this adaptation of James Baldwin’s novel are loving while black, an existential truth that is turned into a nightmare.
# Ron Perlman and Famke Janssen star in this film that finds a hired killer dealing with his own mortality.
# The actress Karen Gillan gets glum to play a depressed young woman in her feature directorial debut.
# In Nathan Silver’s new film, American bros break the hearts of beautiful Frenchwomen. Realism or wishful thinking?
# Flipping from bucolic to brutal with distressing ease, this beautifully realized movie views a Mafia kidnapping through the prism of first love.
# A college newspaper columnist writes about her experiences trading gifts for sex in a film that squanders its good will.
# This lurid melodrama follows a female pimp (Keke Palmer) and her girlfriend-prostitute.
# Sam Boyd’s gentle, loose-limbed romantic comedy wins no prizes for originality.
# Morgan Neville’s movie tells the tumultuous behind-the-scenes story of the making and near-unmaking of “The Other Side of the Wind.”
# The great South Korean director Lee Chang-dong’s latest involves three characters subsumed by desire and rage.
# This cancer drama focuses less on the high stakes of illness than on how two young people talk to each other in sickness and in health.
# A documentary reveals its octogenarian subject as still busy and productive, and not a little haunted by memories of friends now gone.
# Adding to the booming genre of comedian documentaries, this film is an affectionate portrait of one of the first major stars of “Saturday Night Live.”
# This documentary with a simple premise — Eileen Atkins, Judi Dench, Joan Plowright and Maggie Smith in conversation — delivers insight and gossip.
# Julianne Moore plays an opera singer trapped in a South American mansion in this disappointingly passionless film.
# This Hungarian film is a careful, compassionate and beautifully acted character drama with a social conscience.
# Lisa Immordino Vreeland’s new documentary is about Cecil Beaton, the British dandy, photographer and theatrical designer.
# John Cameron Mitchell’s loony romantic comedy encourages young love to bloom in the soil of an alien visitation.
# Two couples struggle to find serenity as middle age and its multiple discontents come breathing down their necks.
# In this personal movie, the actress Ashley Bell embarks on an elephant rescue in Thailand that also reveals the threats to the animal’s survival.
# A portrait of a filmmaker in crisis that might have worked better as a comedy sketch.
# In Wim Wenders’s film, Alicia Vikander and James McAvoy are soul mates who find each other before a plotline involving Somali jihadists separates them.
# Russ Harbaugh’s debut feature delivers something rarely seen in American movies: a warts-and-all examination of extended grief.
# Edie Falco and Jay Duplass connect romantically in this life-after-prison drama that prioritizes patience and pragmatism over passion.
# This comedy set in a particularly idyllic Atlanta suburb has a gay love story, a blackmailing weasel and surprising emotional resonance.
# A stubborn thirtysomething sentenced to spend time in an autism support group after an arrest finds romance, in this film starring actors with autism.
# Sally Potter directs a very fine cast in a would-be comedy about a calamitously bad evening.
# Set in 1953, when the country was under French colonial rule, the story takes place on a plantation that harbors shameful secrets — and an apparition.
# There are few hard feelings in Bethany Ashton Wolf’s adaptation of a novel by Heidi McLaughlin.
# The documentary looks at the mass killings of kangaroos for pet-food companies, leather processors and ranchers in Australia.
# In Philippe Garrel’s drama, a 23-year-old woman moves in with her father and his 23-year-old girlfriend. Complications ensue.
# This decades-spanning melodrama chronicles the rivalries and heartbreaks of a dance troupe in Mao’s China.
# The true-crime documentary lays out a persuasive case for reasonable doubt in the case against Jens Soering, who was convicted, along with his girlfriend.
# Guillermo del Toro’s latest film is an unlikely and lyrical love story, inspired by “Creature From the Black Lagoon.”
# The rap luminary RZA and the hip-hop musician Azealia Banks team up for a story of rap and poetry, “Love Beats Rhymes.”
# The filmmaker Jon Alpert has been visiting and documenting Cuba for 45 years. His new movie looks back fondly at its people and its leader.
# Kim Min-hee stars in a new film from the prolific South Korean director Hong Sang-soo. The movie has been seen as based partly on their affair.
# In Joachim Trier’s sly psychological thriller “Thelma,” a child-woman finds love and discovers that behaving like a good girl can be a very bad idea.
# This film from Tom Gustafson, based on a 1993 Off Broadway show, has a formidable cast of Broadway names but wants for dramatic traction.
# This ensemble comedy from Michelle Morgan concerns one woman who exits a relationship, and another who seeks one. Their city only complicates matters.
# This feature debut of the writer and director Francis Lee is a bracing, sometimes brutal movie.
# Idris Elba and Kate Winslet crash into a mountain — and each other — in this drama.
# An intimate, affecting film about a couple with autism, as they plan their wedding.
# A sheltered young woman enamored of the films of the famous director sets off to Italy to meet him.
# José María Cabral’s drama concerns a male and female convict in adjacent penitentiaries who use a sign language — “woodpecking” — in order to connect.
# Three married couples outwit a documentary filmmaker in Lake Bell’s sex comedy.
# Twenty-five years after they split, two former high school sweethearts reluctantly reunite for an awkward night.
# A couple break up, but remain together, frustratingly, because of the husband’s financial woes.
# In war-torn Liberia, Charlize Theron and Javier Bardem face a big problem: how to keep their knotty relationship from fizzling.
# In Ingrid Jungermann’s droll comedy, ex-lovers who produce a podcast about serial killers find themselves at odds when a new romantic interest emerges.
# Isabelle Huppert and Louis Garrel star in a screen version of an 18th-century Marivaux play and the last film directed by Luc Bondy.
# In “My Journey Through French Cinema,” Mr. Tavernier’s documentary about movies doubles as an autobiography.
# Kumail Nanjiani stars opposite Zoe Kazan in this very funny, moving true story about how he found and almost lost love. Holly Hunter and Ray Romano also star.
# The filmmakers Fiona Gordon and Dominique Abel star in their fourth movie, a tale infused with physical comedy about a woman in search of her aunt.
# This combination crime drama and romance finds Emile Hirsch and Zoë Kravitz circling each other, and trying to stay away from bad guys.
# Amandla Stenberg plays a teenager with an immune system disorder who falls for the boy next door, and risks everything.
# This feature debut of the Australian filmmaker Ben Young resembles a real-life couple’s killing spree in the 1980s.
# Meet the husband-and-wife team that inspired some of the most memorable moments onscreen, from “The Graduate” to “The Birds.”
# Inspired by a true story, “The Happiest Day in the Life of Olli Maki” is a charmer about a boxer trying to win a championship and find his bliss.
# Oscar Isaac, Christian Bale and Charlotte Le Bon star in this wartime romance with a heavy subject (genocide) but a corny plot.
# François Ozon’s adaptation of Ernst Lubitsch’s 1932 antiwar film, “Broken Lullaby,” is set in Germany and France in the aftermath of World War I.
# This moody romance stars Tatiana Maslany (“Orphan Black”) as a bipolar painter in love with a brooding cabby (Tom Cullen of “Downton Abbey”).
# A nurse travels to the Ottoman Empire on the eve of World War I. Can romance blossom amid earthshaking events?
# Josh Kornbluth runs afoul of the Internal Revenue Service after failing to file tax returns for seven years.
# A messed-up heroine is asked to choose between naughty and nice in Catalina Aguilar Mastretta’s sophomore feature, which is predictable but satisfying.
# This documentary profiles distinctive street cats in Istanbul and the human communities that interact with them.

# %%
titles = []
#print(reviews_list)
for review in reviews_list:
    #print(review)
    print(review['headline']['print_headline'])
    titles.append(review['headline']['print_headline'])
# Out:
# The Attachment Diaries
# What’s Love Got to Do With It?
# You Can Live Forever
# A Tourist’s  Guide to Love
# Intoxicating Love With a Sobering Turn
# One True Loves
# The Lost Weekend:  A Love Story
# An Unbending Will Meets a Shifting City
# They Have a Humdrum Kind of Love
# Love in the Time Of Fentanyl
# Pamela, a Love Story
# In From the Side
# After Love
# Alcarràs
# Nelly &amp; Nadine
# A Love Whose Name Is Often Spoken
# The Sound  Of Christmas
# A Few Good Men, Some With Secrets
# It’s Eat, Prey, Love on a Journey of Self-Discovery
# My Policeman
# About Fate
# Waiting for Bojangles
# A Father Catfishes His Son. We Just Wait for the Ick.
# The Romantic Ache That Never Truly Dies
# Alone Together
# Art of Love
# The Wheel
# He’s Still a Norse God, But Also a Big Old Goof
# A Bliss Doomed To Be Doused
# A Volcanic Romance Across Continents
# Love &amp; Gelato
# Stay Prayed Up
# A Poet’s Life, In Love and War
# Dinner in America
# In a New York Minute
# Portrait of a Restless Heart
# I Love America
# The Persistent Melancholy of Love
# La Mami
# Love After Love
# A Non-Erotic Non-Thriller
# Lucy and Desi
# Who Gets to Write the Book of Love?
# The In Between
# Book of Love
# Love, Ferocious and Limitless
# The Pink Cloud
# Reflections on Love That’s Built and Lost
# Meeting a Girl Named Maria, Again
# Aulcie
# Love Is Love Is Love
# Love Hard
# Scenes From Not Quite a Marriage
# Hard Luck Love Song
# South of Heaven
# Marriage Amid Nationalism
# Happier Than Ever:  A Love Letter  to Los Angeles
# Love and Loathing in a Blighted London
# A Star Is Born. You Won’t Like Him.
# Her Ex Returns, With His Bride-to-Be
# Three Days of Violence, Misogyny and $4 Water
# Casanova, Last Love
# Running Against the Wind
# Asia
# She’s Like a Sprite Out of Water
# This Town
# Tu Me Manques
# Monday
# This Is Somehow a Love That’s Worth Killing For
# So Many Siblings  Seeking One Another
# Luz
# Happily
# A Love Letter to 1990s California Hip-Hop
# A Rom-Com Sequel That May Cause Cavities
# Young Hearts
# Little Fish
# Two of Us
# Atlantis
# Neurosurgeon, Heal Thyself
# Your Name Engraved Herein
# Young Lovers Swoon, as Young Lovers Should
# Excuse Me, the Feeling Is Mutual
# Museum Town
# Wild Mountain Thyme
# Acid and Romance: On the Run With Timothy Leary
# Loved in Hip-Hop, but Loathed in the End
# Love on the Rocks
# Love and Monsters
# A Love Letter Delivered Along With a Death Notice
# Love, Guaranteed
# A Young Troupe Needs Some Ballet Tough Love
# Love Means Never Having, Well, You Know
# Love of Language Spells Success
# Making a Haven of Their Own
# Pratfalling Down The Aisle
# Schooled in Romance, but Missing Class
# Hope Gap
# A Refreshing Exploration of Mental Illness
# An Unabashedly Old-School Love Story
# Designing a Love Story
# Old-Sweater Lives
# Follow Your Bliss While It Lasts, Kids
# A Special Spot  In Her Heart
# Love Simmers Inside a Cauldron
# Friendly Split, Shattering Break
# Cyrano, My Love
# Pretenders
# Assassin Variations, by Way of Japan
# Corruption and Charisma Personified
# A Fine Romance to Watch While Sorting Socks
# Hot Air
# Love, Antosha
# Leto
# They Whirl, They Twirl, They Tango
# Falling For a Drifter And His Lookalike
# A Beautiful Day for Young Hearts
# None
# Beating the Odds for Love and Bliss
# Clara
# An Extravagant Spectacle
# Rafiki
# A Vibrant Tale of Love, Sisterhood and Decline
# Five Feet Apart
# Gangsters’ Paradise Lost, in China
# Love, and Some Laughter, Is in the Air
# Exploring the Roots of Life Itself, With Love
# The Hole  in the Ground
# Love Takes Wing Amid Trouble in Utopia
# Love Notes Forge a Caribbean Bond
# They Show Their Love With a Body Slam
# Attraction: That’s the Easy Part
# Berlin, I Love You
# Untogether
# A Resonating Love Shall Guide You
# Love Is Forced to Live in a Nightmare
# Asher
# Topical Depression Above Scotland
# The Great Pretender
# Love in an Enchanted Forest Turns Eerie
# The New Romantic
# Pimp
# In a Relationship
# The Legend Behind The Scenes
# Love Ignites a Divided World
# After Everything
# The Man Behind the Music
# Eccentric Charm, Raucous Abandon
# Tea With the Dames
# This Hostage Can Hold a Tune
# The Citizen
# Love, Cecil
# Otherworldly Love in a Punk-Rock World
# Rogers Park
# Love &amp; Bananas: An Elephant Story
# A Portrait and, for Some, a Hate-Watch
# They Find Each Other, Then Geopolitics Set In
# Love After Love
# On Parole and in Love
# Coming Out Is Complicated
# Keep the Change
#   Invite Company. Because After All, Misery Loves It.
# The Housemaid
# Hitting  Pause On Love
# Kangaroo: A Love-Hate Story
# A Love Triangle With Angles That Are Awkward
# Youth
# Killing for Love
# A Monster Worthy of Love
# Love Beats Rhymes
# Cuba and the Cameraman
# Fiction, With Real Life Getting in the Way
# A Woman in Love Can Burn Down the World
# Decades of Musical Love and Lust
# It Happened in L.A.
# Love Is Wild, if Not Always Pretty
# The Mountain Between Us
# Dina
# In Search of Fellini
# Woodpeckers
# I Do ... Until I Don’t
# Tales of an Immoral Couple
# After Love
# The Last Face
# Killer Lines, Dangerous Dates
# Insolvent Gentleman Seeks Love
# Reflecting on a Lifelong Love
# Love and (Almost) Death
# Lost in Paris
# Vincent N Roxxy
# Everything, Everything
# Hounds of Love
# Harold and Lillian: A Hollywood Love Story
# Love and Life on the Ropes
# A Love Triangle, Near the Front Lines
# The Wounds of War and Love
# Review: A Combustible Pair Find Love in ‘The Other Half’
# Review: Love as the World Wars, in ‘The Ottoman Lieutenant’
# It’s Inevitable, Mirth and Taxes
# Everybody Loves Somebody
# Kedi

# %%
# Create an empty list to store the reviews


# loop through pages 0-19

    # create query with a page number
    # API results show 10 articles at a time

    
    # Make a "GET" request and retrieve the JSON

    
    # Add a twelve second interval between queries to stay within API query limits

    
    # Try and save the reviews to the reviews_list

        # loop through the reviews["response"]["docs"] and append each review to the list

        # Print the page that was just retrieved


        # Print the page number that had no results then break from the loop

# %%
# Preview the first 5 results in JSON format
print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
df_reviews = pd.json_normalize(reviews_list)
print(df_reviews)
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
df_reviews["title"] = df_reviews["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
df_reviews["keywords"] = df_reviews["keywords"].apply(extract_keywords)

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = df_reviews["title"].tolist()

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
tmdb_search_url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1


for title in titles:
# Loop through the titles

    # Check if we need to sleep before making a request
    if request_counter % 50 == 0:
        print("Going to sleep")
        time.sleep(1)

    # Add 1 to the request counter
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    query_url = f"{tmdb_search_url}{title}{tmdb_key_string}"
    movies = requests.get(query_url).json()
    print(movies)
    
    try:
        for movie_details in movies['results']:
           # print("Here")
        
            #tmdb_movies_list.append(movie['id'])
            # Extract the production_countries' name into a list
            genres = [genre["name"] for genre in movie_details.get("genres", [])]
            spoken_languages = [language["english_name"] for language in movie_details.get("spoken_languages", [])]
            production_countries = [country["name"] for country in movie_details.get("production_countries", [])]

            # Add the relevant data to a dictionary and
            # append it to the tmdb_movies_list list
            movie_dict = {
                "title": title,
                "original_title": movie_details.get("original_title"),
                "budget": movie_details.get("budget"),
                "original_language": movie_details.get("original_language"),
                "homepage": movie_details.get("homepage"),
                "overview": movie_details.get("overview"),
                "popularity": movie_details.get("popularity"),
                "runtime": movie_details.get("runtime"),
                "revenue": movie_details.get("revenue"),
                "release_date": movie_details.get("release_date"),
                "vote_average": movie_details.get("vote_average"),
                "vote_count": movie_details.get("vote_count"),
                "genres": genres,
                "spoken_languages": spoken_languages,
                "production_countries": production_countries
            }

            # Append the dictionary to the list
            tmdb_movies_list.append(movie_dict)
            print(f"Movie '{title}' found and added to the list.")
    except:
        print("No movies found")

    # Include a try clause to search for the full movie details.
#         movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"
#         movie_response = requests.get(movie_url)
#         movie_details = movie_response.json()
    
    # Use the except clause to print out a statement if a movie
    # is not found.

        # Get movie id


        # Make a request for a the full movie details


        # Execute "GET" request with url

        
        # Extract the genre names into a list


        # Extract the spoken_languages' English name into a list


        
    

        
        # Print out the title that was found
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': None, 'genre_ids': [18, 9648, 53, 27], 'id': 743040, 'original_language': 'es', 'original_title': 'El apego', 'overview': 'Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.', 'popularity': 5.33, 'poster_path': '/hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg', 'release_date': '2021-10-07', 'title': 'The Attachment Diaries', 'video': False, 'vote_average': 3.0, 'vote_count': 4}], 'total_pages': 1, 'total_results': 1}
# Movie 'The Attachment Diaries' found and added to the list.
# {'page': 1, 'results': [], 'total_pages': 1, 'total_results': 0}
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg', 'genre_ids': [18, 10749], 'id': 887580, 'original_language': 'en', 'original_title': 'You Can Live Forever', 'overview': "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.", 'popularity': 36.875, 'poster_path': '/6JllNMDqHasBeqM5vFVxp1rB9Fk.jpg', 'release_date': '2023-03-24', 'title': 'You Can Live Forever', 'video': False, 'vote_average': 6.611, 'vote_count': 36}], 'total_pages': 1, 'total_results': 1}
# Movie 'You Can Live Forever' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/z3Qc5a0grcCREAQKqI195P05dVf.jpg', 'genre_ids': [10749, 35], 'id': 813726, 'original_language': 'en', 'original_title': "A Tourist's Guide to Love", 'overview': 'After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.', 'popularity': 16.426, 'poster_path': '/uWkpjbBe4gRZilXRXbYfsMUZMhz.jpg', 'release_date': '2023-04-21', 'title': "A Tourist's Guide to Love", 'video': False, 'vote_average': 6.291, 'vote_count': 160}], 'total_pages': 1, 'total_results': 1}
# Movie 'A Tourist’s Guide to Love' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/lPVDTVYrnIBj0AwZ4NPf5TnDEfz.jpg', 'genre_ids': [18, 35], 'id': 803694, 'original_language': 'fr', 'original_title': 'Les Enfants des autres', 'overview': 'Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn’t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?', 'popularity': 9.846, 'poster_path': '/4vsQ4894pzd7nbvP5FoSOHaS1mI.jpg', 'release_date': '2022-09-21', 'title': "Other People's Children", 'video': False, 'vote_average': 6.823, 'vote_count': 189}, {'adult': False, 'backdrop_path': None, 'genre_ids': [10751], 'id': 100744, 'original_language': 'da', 'original_title': 'Andre folks børn', 'overview': "The sympathetic farmers couple, Mads and Katrine (Hass Christensen and Malberg) are marked by their daughter's death. Katrine has to avoid other children. When Mads invites six city children for the summer holiday, however, old traumas are recovered.", 'popularity': 0.234, 'poster_path': '/3vgR6GcQMIlUYeooNMGrsAVXzlD.jpg', 'release_date': '1958-01-01', 'title': "Other People's Children", 'video': False, 'vote_average': 4.0, 'vote_count': 2}, {'adult': False, 'backdrop_path': '/uMcqggoN9Jl95TN4vuOtUxslguA.jpg', 'genre_ids': [10749, 18], 'id': 370725, 'original_language': 'en', 'original_title': "Other People's Children", 'overview': 'A filmmaker, reeling from the death of her famous father, falls down the rabbit hole of a charismatic homeless man who becomes the subject of her latest documentary and her new love interest.', 'popularity': 3.99, 'poster_path': '/urHTo7MpJxpzEaFW9rl5BQvC7Nu.jpg', 'release_date': '2015-12-25', 'title': "Other People's Children", 'video': False, 'vote_average': 4.0, 'vote_count': 8}, {'adult': False, 'backdrop_path': None, 'genre_ids': [99], 'id': 1149860, 'original_language': 'ru', 'original_title': 'Чужие дети', 'overview': 'Two generations of cinematographers — fathers and children — in search of a new common language: in life, on the screen, on the set...', 'popularity': 0.007, 'poster_path': None, 'release_date': '2006-07-07', 'title': "Other People's Children", 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 575043, 'original_language': 'en', 'original_title': "Other People's Children", 'overview': "A series of home move style shots of a mother and her young child crawling outdoors. Scenes include a mother and toddler playing in a Chicago backyard, a young family boating in a small lake, toddlers playing & bathing outdoors, a young girl and her stuffed animal and a children's birthday party with a pi?ata. Exact date of production is unknown.", 'popularity': 0.004, 'poster_path': None, 'release_date': '1978-01-01', 'title': "Other People's Children", 'video': False, 'vote_average': 0.0, 'vote_count': 0}], 'total_pages': 1, 'total_results': 5}
# Movie 'Other People’s Children' found and added to the list.
# Movie 'Other People’s Children' found and added to the list.
# Movie 'Other People’s Children' found and added to the list.
# Movie 'Other People’s Children' found and added to the list.
# Movie 'Other People’s Children' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/omkxkjj0IEhzOc9CBOwK2lrmHSk.jpg', 'genre_ids': [10749, 18, 35], 'id': 846961, 'original_language': 'en', 'original_title': 'One True Loves', 'overview': 'Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.', 'popularity': 12.611, 'poster_path': '/6MF3JvIZkluUijw9rvDKNqPT8kC.jpg', 'release_date': '2023-04-07', 'title': 'One True Loves', 'video': False, 'vote_average': 6.458, 'vote_count': 72}, {'adult': False, 'backdrop_path': None, 'genre_ids': [18], 'id': 893629, 'original_language': 'ru', 'original_title': 'Однолюбы', 'overview': 'The story is about old village residents who, due to the expansion of the collective farm, have to leave their huts and their homes.', 'popularity': 1.639, 'poster_path': '/sNlGmO2wWfjpCmYuOikDvXmkb8O.jpg', 'release_date': '1983-07-13', 'title': 'One True Love', 'video': False, 'vote_average': 0.0, 'vote_count': 0}], 'total_pages': 1, 'total_results': 2}
# Movie 'One True Loves' found and added to the list.
# Movie 'One True Loves' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/uTEvYDLrhrtW57ntM3EbRpgmlZm.jpg', 'genre_ids': [99], 'id': 965042, 'original_language': 'en', 'original_title': 'The Lost Weekend: A Love Story', 'overview': 'May Pang lovingly recounts her life in rock & roll and the whirlwind 18 months spent as friend, lover, and confidante to one of the towering figures of popular culture, John Lennon, in this funny, touching, and vibrant portrait of first love.', 'popularity': 4.28, 'poster_path': '/qlbOj1G3YtIDUGSzu1Y590EfSMY.jpg', 'release_date': '2023-04-13', 'title': 'The Lost Weekend: A Love Story', 'video': False, 'vote_average': 6.0, 'vote_count': 2}], 'total_pages': 1, 'total_results': 1}
# Movie 'The Lost Weekend: A Love Story' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/7NTGZTzqWHgBJeoNaWsAxvHtRy4.jpg', 'genre_ids': [18, 80], 'id': 855263, 'original_language': 'en', 'original_title': 'A Thousand and One', 'overview': 'Struggling but unapologetically living on her own terms, Inez is moving from shelter to shelter in mid-1990s New York City. With her 6-year-old son Terry in foster care and unable to leave him again, she kidnaps him so they can build their life together. As the years go by, their family grows and Terry becomes a smart yet quiet teenager, but the secret that has defined their lives threatens to destroy the home they have so improbably built.', 'popularity': 10.103, 'poster_path': '/yW97MlBddOeiw17zUSf2iWvOmkr.jpg', 'release_date': '2023-03-31', 'title': 'A Thousand and One', 'video': False, 'vote_average': 6.903, 'vote_count': 88}, {'adult': False, 'backdrop_path': '/hH7p7r2yn6AhckdEW7Z5MNMsWFP.jpg', 'genre_ids': [16, 18, 14, 27], 'id': 85398, 'original_language': 'ja', 'original_title': '千夜一夜物語', 'overview': 'Aldin, a vagabond water vendor, embarks of a series of fantastical and tragic misadventures through the Middle East in search of love, fortune, and power.', 'popularity': 11.971, 'poster_path': '/lWigWlmWTcq8lHYh4WKUY8gQh6u.jpg', 'release_date': '1969-06-14', 'title': 'A Thousand and One Nights', 'video': False, 'vote_average': 6.8, 'vote_count': 46}, {'adult': False, 'backdrop_path': '/sMwdNcfiEOflpfvP6eDX5OLGGQA.jpg', 'genre_ids': [12, 35, 14], 'id': 90984, 'original_language': 'en', 'original_title': 'A Thousand and One Nights', 'overview': "On the run after being found sweet-talking the Sultan's daughter, Aladdin comes upon a lamp which, when rubbed, summons up Babs the genie. He uses it to return as a visiting prince asking for the princess's hand. Unfortunately for him, the sultan's wicked twin brother has secretly usurped the throne, someone else is after the lamp for his own ends, and Babs has taken a shine to Aladdin herself and is bent on wrecking his endeavours.", 'popularity': 5.384, 'poster_path': '/1XfX58k7OlItR3wfSyPg0tS9JfK.jpg', 'release_date': '1945-07-20', 'title': 'A Thousand and One Nights', 'video': False, 'vote_average': 5.6, 'vote_count': 14}, {'adult': False, 'backdrop_path': '/nSIrVPrBszqAiAUgxXbUTqVn7WL.jpg', 'genre_ids': [16, 12, 14], 'id': 46657, 'original_language': 'cs', 'original_title': 'Pohádky tisíce a jedné noci', 'overview': 'Five different exploits of Sinbad the sailor where he gets mixed up with the pretty daughters of exotic potentates, with powerful monsters that threaten his existence, and with all sorts of teeming jungle life.', 'popularity': 1.436, 'poster_path': '/9kwA0mlVi47VaKKREHS5I58emI6.jpg', 'release_date': '1974-11-01', 'title': 'A Thousand and One Nights', 'video': False, 'vote_average': 6.1, 'vote_count': 11}, {'adult': False, 'backdrop_path': None, 'genre_ids': [18], 'id': 1211193, 'original_language': 'ja', 'original_title': '東宝千一夜', 'overview': 'The debut film of Shin Toho Productions', 'popularity': 1.162, 'poster_path': '/r3zEgkgacPEyxdv6VlvpkWOPQUc.jpg', 'release_date': '1947-02-25', 'title': 'A Thousand and One Nights with Toho', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': None, 'genre_ids': [35], 'id': 327775, 'original_language': 'ar', 'original_title': 'ألف ليلة وليلة', 'overview': "Othman, a fisherman, finds a baby inside a floating basket while fishing, so he takes him, raises him and teaches him fishing. Othman gets arrested for fishing in a protected area, but the prince's daughter intervenes to exempt him. A genie than appears to Othman and tells him the story of his adopted son Morgan.", 'popularity': 0.426, 'poster_path': '/wCGFhNMIPgAmY9TGTmq7geOva03.jpg', 'release_date': '1941-03-20', 'title': 'A Thousand and One Nights', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/yUw233N4Pab06btTBTFNk4A9Bix.jpg', 'genre_ids': [18], 'id': 649798, 'original_language': ' ...
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# Movie 'A Thousand and One' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/u6HeK9nl6p2MAKSxHF613LOhuFM.jpg', 'genre_ids': [10749, 35], 'id': 703451, 'original_language': 'en', 'original_title': 'Your Place or Mine', 'overview': "When best friends and total opposites Debbie and Peter swap homes for a week, they get a peek into each other's lives that could open the door to love.", 'popularity': 26.762, 'poster_path': '/3oFfY1HpzJDlRzKSCBF2sA5mb9U.jpg', 'release_date': '2023-02-10', 'title': 'Your Place or Mine', 'video': False, 'vote_average': 6.281, 'vote_count': 708}, {'adult': False, 'backdrop_path': '/vilbeuVA5ntHJcCkqDjYFyIbmg8.jpg', 'genre_ids': [35, 10749], 'id': 359490, 'original_language': 'cn', 'original_title': '每天愛您８小時', 'overview': 'Your Place or Mine! explores the difficulties of finding true love in the modern Hong Kong setting via the encounters of two advertising executives, Wai and Patrick. Wai is a faithful guy who often falls for the girl that he grooms. However he is often dumped by them once they found fame and someone better than him. Just when he was about to give up on finding true love, he met an innocent fish ball seller and a tough boss who both falls for him and left him even more undecided in love. Patrick on the other hand is a playboy who keeps a girlfriend at home while frequently has one night stands outside. Can a colleague who has crush on him since school days change his cheating ways?', 'popularity': 2.431, 'poster_path': '/oo7wKs1UeT9tMNFyzu6NVXPJBAe.jpg', 'release_date': '1998-09-25', 'title': 'Your Place or Mine!', 'video': False, 'vote_average': 4.75, 'vote_count': 5}, {'adult': False, 'backdrop_path': '/6plkIEUSgqyTxDFvvSXBJA6lNX1.jpg', 'genre_ids': [10749, 35, 18], 'id': 351800, 'original_language': 'tl', 'original_title': 'Your Place or Mine?', 'overview': "One night with a total stranger. And fate brought them together once again. That's where their whirlwind romance started.", 'popularity': 1.768, 'poster_path': '/9Yr5rGzNFi9NY7cZk3RDpPgf1YW.jpg', 'release_date': '2015-04-29', 'title': 'Your Place or Mine?', 'video': False, 'vote_average': 6.5, 'vote_count': 2}, {'adult': False, 'backdrop_path': None, 'genre_ids': [35, 10770], 'id': 726421, 'original_language': 'en', 'original_title': 'Your Place... or Mine?', 'overview': "Karen (Tyne Daly) is a San Francisco real estate broker and best friend of psychiatrist Alexandra Benedict (Bonnie Franklin) whose boyfriend leaves her. Karen's husband Phillip (Peter Bonerz) plays rugby with gardener Nick Richmond (Robert Klein) who Karen thinks is the perfect match for Alexandra, but circumstances stop Alexandra from meeting Nick until the last minutes of the narrative.", 'popularity': 1.8, 'poster_path': '/m37Jonf8d4lFenyWBldeXXsmF9o.jpg', 'release_date': '1983-03-02', 'title': 'Your Place... or Mine?', 'video': False, 'vote_average': 0.0, 'vote_count': 0}], 'total_pages': 1, 'total_results': 4}
# Movie 'Your Place or Mine' found and added to the list.
# Movie 'Your Place or Mine' found and added to the list.
# Movie 'Your Place or Mine' found and added to the list.
# Movie 'Your Place or Mine' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/lE8xquVrAf5UiUA8pzBxxdp2vPH.jpg', 'genre_ids': [99], 'id': 976653, 'original_language': 'en', 'original_title': 'Love in the Time of Fentanyl', 'overview': 'An intimate portrait of a community fighting to save lives and keep hope alive in a neighborhood ravaged by the overdose crisis.', 'popularity': 1.785, 'poster_path': '/rSAhu53e2WgHZZX2oiXnzxr3Q09.jpg', 'release_date': '2023-02-03', 'title': 'Love in the Time of Fentanyl', 'video': False, 'vote_average': 0.0, 'vote_count': 0}], 'total_pages': 1, 'total_results': 1}
# Movie 'Love in the Time of Fentanyl' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/aJvgoRMrYFTMu7MrcfxYVPMRuU5.jpg', 'genre_ids': [99], 'id': 1061671, 'original_language': 'en', 'original_title': 'Pamela, A Love Story', 'overview': 'In her own words, through personal video and diaries, Pamela Anderson shares the story of her rise to fame, rocky romances and infamous sex tape scandal.', 'popularity': 10.614, 'poster_path': '/zkVnRwZWbrd55P3Tx7BZZQ1gU89.jpg', 'release_date': '2023-01-30', 'title': 'Pamela, A Love Story', 'video': False, 'vote_average': 6.978, 'vote_count': 207}], 'total_pages': 1, 'total_results': 1}
# Movie 'Pamela, a Love Story' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/tfC2q3BPJIQW28sOexF8SYUYV5j.jpg', 'genre_ids': [18, 10749], 'id': 622082, 'original_language': 'en', 'original_title': 'In from the Side', 'overview': 'Mark, a new and inexperienced rugby club member, finds himself drawn to Warren, a seasoned first team player. When a series of happenstances at an away fixture lead to a drunken encounter, Mark and Warren unwittingly embark on a romantic affair they struggle to hide from their partners and teammates.', 'popularity': 18.786, 'poster_path': '/3ZJzL6L0RFVBg6qa2CDAXxXxJjC.jpg', 'release_date': '2022-09-16', 'title': 'In from the Side', 'video': False, 'vote_average': 6.8, 'vote_count': 62}, {'adult': False, 'backdrop_path': None, 'genre_ids': [18], 'id': 1164212, 'original_language': 'ru', 'original_title': 'Зять из провинции', 'overview': 'About a young guy from the province who enters into an unequal struggle with the mafia.', 'popularity': 0.003, 'poster_path': '/tSXvf2fJBD5ghSn58bd1NQ3JoLU.jpg', 'release_date': '1987-08-01', 'title': 'The Brother-in-law from the Country Side', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/cDA5NGs3o8mdgxqlqEGrDi56z2B.jpg', 'genre_ids': [16, 18, 9648, 14], 'id': 802699, 'original_language': 'ja', 'original_title': 'とつくにの少女', 'overview': 'Once upon a time, in a far, faraway place, there were two lands. The world was divided into an inner land and an outer land. People feared the outer land, inhabited by eerie beings, the carriers of curse. One day, on the border to the inner land inhabited by humans, one such being finds a girl on heaps of abandoned dead bodies. The girl says her name is Shiva and shows affection to the "being" who found her, calling him "Teacher."  This is a story of two people—one human, one inhuman—who linger in the hazy twilight that separates night from day.', 'popularity': 14.839, 'poster_path': '/pxetgBMAyDg8dorRApnHPKvD74g.jpg', 'release_date': '2023-05-16', 'title': 'The Girl from the Other Side', 'video': False, 'vote_average': 6.9, 'vote_count': 10}, {'adult': False, 'backdrop_path': '/eY4BAALgevSTeh2QqFbkDz1HMu7.jpg', 'genre_ids': [10402], 'id': 795628, 'original_language': 'de', 'original_title': 'Blind Guardian - Imaginations From The Other Side - Live In Oberhausen', 'overview': 'Live at Turbinenhalle, Oberhausen, Germany, December 3, 2016  1. Imaginations from the Other Side 8:26  2. I’m Alive 5:40  3. A Past and Future Secret 4:13  4. The Script for My Requiem 6:32  5. Mordred’s Song 5:20  6. Born in a Mourning Hall 5:37  7. Bright Eyes 5:41  8. Another Holy War 5:02  9. And the Story Ends 7:18', 'popularity': 0.36, 'poster_path': '/v4Hvw8stiwPZDwhbYrvlVFdj4N.jpg', 'release_date': '2020-12-11', 'title': 'Blind Guardian - Imaginations From The Other Side - Live In Oberhausen', 'video': False, 'vote_average': 8.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/zxfgAqyVDepFmUY5W7w9pNvJZVg.jpg', 'genre_ids': [10749, 18], 'id': 109302, 'original_language': 'ja', 'original_title': '打ち上げ花火、下から見るか？横から見るか？', 'overview': "One summer day, a group of sixth-grade boys have an argument about whether fireworks are round or flat when viewed from different angles and embark on a journey for the answer during the annual firework festival. Meanwhile, one of their classmates, Nazuna, is troubled by her parents' separation and decides to choose one of the boys to run away with.", 'popularity': 10.258, 'poster_path': '/gO7QL3yiYoWWKyOmiizINXiZ9Fr.jpg', 'release_date': '1995-08-12', 'title': 'Fireworks, Should We See It from the Side or the Bottom?', 'video': False, 'vote_average': 7.086, 'vote_count': 29}, {'adult': False, 'backdrop_path': '/ec2HbgYBbx2E84EekUuyAbDw5ww.jpg', 'genre_ids': [16, 14], 'id': 587873, 'original_language': 'ja', 'original_title': 'とつくにの少女', 'overview': 'Touch not the Outsiders, lest ye become an Outsider. But when two creatures belonging to opposite kinds - a lost little girl from the Inside and a de ...
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# Movie 'In From the Side' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/xgxdY4puoffYlCrfSumQt9xULFR.jpg', 'genre_ids': [18], 'id': 714011, 'original_language': 'en', 'original_title': 'After Love', 'overview': 'Set in the port town of Dover in the South-East of England, Mary Hussain suddenly finds herself a widow following the unexpected death of her husband. A day after the burial, she discovers he has a secret just twenty-one miles across the English Channel in Calais.', 'popularity': 20.945, 'poster_path': '/mXaNg69iWEs0Qsj4AJxcvCXuWKw.jpg', 'release_date': '2021-06-04', 'title': 'After Love', 'video': False, 'vote_average': 7.152, 'vote_count': 122}, {'adult': False, 'backdrop_path': '/r5ZZYShwbbakdTnhgOjj7GKkgm0.jpg', 'genre_ids': [10749, 99], 'id': 1220450, 'original_language': 'pt', 'original_title': 'Casamento às Cegas Brasil: Depois do Altar', 'overview': 'Drama, closure and rekindled flames collide as cast members from past seasons of "Love is Blind Brazil" come together in this special reunion episode.', 'popularity': 4.87, 'poster_path': '/qRNPA0pjTNEZuLEuhF1CeOzpwWS.jpg', 'release_date': '2023-12-20', 'title': 'Love Is Blind Brazil: After the Altar', 'video': False, 'vote_average': 6.2, 'vote_count': 3}, {'adult': False, 'backdrop_path': '/8NJhybNBFswAIbUFUy7fZcfh8QM.jpg', 'genre_ids': [18], 'id': 377278, 'original_language': 'fr', 'original_title': "L'économie du couple", 'overview': 'Marie and Boris decide to get a divorce after 15 years of marriage. Tensions rise when cash-strapped Boris must continue to live with Marie and the two children while trying to figure out how to divide the assets.', 'popularity': 8.548, 'poster_path': '/98Q38iZx8eHZLVuyFMF7dPMvyzJ.jpg', 'release_date': '2016-06-08', 'title': 'After Love', 'video': False, 'vote_average': 6.083, 'vote_count': 115}, {'adult': False, 'backdrop_path': '/38eDFNP3L58iCHkBkiFwr2aJp8W.jpg', 'genre_ids': [18], 'id': 660002, 'original_language': 'zh', 'original_title': '第一炉香', 'overview': 'The film tells the story of a young girl who travels from Shanghai to Hong Kong in pursuit of education, but ends up working for her aunt seducing rich and powerful men.', 'popularity': 7.724, 'poster_path': '/pMeg2foOwZVB67J7SA6vF291uZL.jpg', 'release_date': '2021-10-22', 'title': 'Love After Love', 'video': False, 'vote_average': 5.574, 'vote_count': 27}, {'adult': False, 'backdrop_path': '/fhPrORpoeqxBUiO5s6KlF2DOlsq.jpg', 'genre_ids': [18, 10749], 'id': 647162, 'original_language': 'ko', 'original_title': '사랑후애', 'overview': "Kim Sung-Joon (Park Si-Hoo) worked as a pilot, but after becoming in deaf in his right ear he has worked on the ground. He becomes desperate. Kim Sung-Joon then meets Eun-Hong (Yoon Eun-Hye) on a blind date. Even though he doesn't love her, he gets married to Eun-Hong. After their marriage, Sung-Joon treats Eun-Hong with indifference. Suddenly, Eun-Hong dies. Kim Sung-Joon soon learns for the first time about her real heart and her first love. Holding Eun-Hong's urn, he seeks out her first love.", 'popularity': 28.685, 'poster_path': '/bx485pM8E9zcmlCDE9AWhmJt7XV.jpg', 'release_date': '2016-05-14', 'title': 'After Love', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/uAIOqdlbGXCvjixu8irTBn7CTSI.jpg', 'genre_ids': [53, 80], 'id': 408117, 'original_language': 'pt', 'original_title': 'A Morte Transparente', 'overview': "Beto, a young gigolo playboy, convinces his friends to break into a house to rape Marlene, a wealthy woman. They can not complete the mission, but the woman fall in love with Beto, who returns to become her lover. The case of the two, eventually involving the husband of Marlene, causes problems that the two can't solve.", 'popularity': 1.688, 'poster_path': '/2OArECHFmZb2QNa2g21noJau4mY.jpg', 'release_date': '1978-12-23', 'title': "Runnin' After Love", 'video': False, 'vote_average': 5.1, 'vote_count': 7}, {'adult': False, 'backdrop_path': '/xo6wShfbmdaIsnVFPl1nO0EDlec.jpg', 'genre_ids': [10749, 18], 'id' ...
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# Movie 'After Love' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/5sl6GEHjvo0V2lGYlcCghTkUUzK.jpg', 'genre_ids': [18], 'id': 804251, 'original_language': 'ca', 'original_title': 'Alcarràs', 'overview': 'In a small village in Catalonia, the peach farmers of the Solé family spend every summer together picking fruit from their orchard. But when plans arise to install solar panels and cut down trees, the members of this tight-knit group suddenly face eviction – and the loss of far more than their home.', 'popularity': 14.598, 'poster_path': '/sbFVJZAvd7a7n2aHEUtOyrQtAKo.jpg', 'release_date': '2022-04-29', 'title': 'Alcarràs', 'video': False, 'vote_average': 6.867, 'vote_count': 180}], 'total_pages': 1, 'total_results': 1}
# Movie 'Alcarràs' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/evGlZtheDf2sDZZA5Vg8RzgES02.jpg', 'genre_ids': [18, 10749], 'id': 12652, 'original_language': 'fr', 'original_title': 'Nelly et Mr. Arnaud', 'overview': 'Nelly leaves her lazy, unemployed husband to work for retired judge Mr Arnaud, forty years her senior, after he offers to clear her bills for her. While she types his memoirs the two develop a close friendship, but Arnaud becomes jealous when Nelly begins dating his good-looking young publisher.', 'popularity': 15.338, 'poster_path': '/87kKTPi9r7YIVrlo9Z42NwTXBVi.jpg', 'release_date': '1995-08-23', 'title': 'Nelly and Monsieur Arnaud', 'video': False, 'vote_average': 6.888, 'vote_count': 120}, {'adult': False, 'backdrop_path': '/wtX5ghyrFyRV4kcixXgjVz6Ak1S.jpg', 'genre_ids': [10751, 14, 12], 'id': 643537, 'original_language': 'sv', 'original_title': 'Nelly Rapp - monsteragent', 'overview': "Nelly and her dog London are about to spend autumn break with her uncle Hannibal. Soon she noticed that he doesn't live a quiet life. Her uncle is a Monster agent. Nelly gets dragged in to an adventure filled with ghosts, vampires and werewolves.", 'popularity': 6.323, 'poster_path': '/x90uEqfpj0voiXOSxBWWrp8yX0h.jpg', 'release_date': '2020-10-23', 'title': 'Nelly Rapp – Monster Agent', 'video': False, 'vote_average': 4.7, 'vote_count': 10}, {'adult': False, 'backdrop_path': '/aPb1xCG2leRKwaEyeBaSD6RNdQV.jpg', 'genre_ids': [16, 10751, 12], 'id': 490694, 'original_language': 'fr', 'original_title': 'Nelly et Simon : Mission Yéti', 'overview': 'Quebec, 1956. The impulsive and headstrong Nelly Maloye, a novice private eye, joins the methodical and pragmatic Simon Picard, a research scientist in a dubious quest to prove the existence of the elusive Yeti. The brave-hearted heroes come face-to-face with countless dangers during their trek through the heart of the Himalayas.', 'popularity': 9.099, 'poster_path': '/kOkneb52OKjvNuPIJCJLUBNQtF5.jpg', 'release_date': '2017-10-05', 'title': 'Mission Kathmandu: The Adventures of Nelly & Simon', 'video': False, 'vote_average': 5.6, 'vote_count': 31}, {'adult': False, 'backdrop_path': '/gfJqphas2iL9B7KMtP4Bo7bOcNS.jpg', 'genre_ids': [12, 35, 10751, 14], 'id': 1088530, 'original_language': 'sv', 'original_title': 'Nelly Rapp - Dödens spegel', 'overview': "Nelly and the dog London are joined by Valle as they head out into the Black Forest to find the Mirror of Death. A journey that takes them deeper and deeper into the forest and to the place where Nelly's mother once disappeared.", 'popularity': 3.66, 'poster_path': '/yVM22R6w5oY8VnUT76dI8dyZ2Nu.jpg', 'release_date': '2023-10-20', 'title': 'Nelly Rapp - The Dark Forest', 'video': False, 'vote_average': 7.2, 'vote_count': 6}, {'adult': False, 'backdrop_path': '/iOACR0rQdakdf4txH4M22n4BwcG.jpg', 'genre_ids': [99], 'id': 916437, 'original_language': 'sv', 'original_title': 'Nelly och Nadine', 'overview': 'Nelly and Nadine meet in Ravensbrück concentration camp. They spend the rest of their lives together. Decades later, Nelly’s granddaughter goes in search of clues. A poignant film about a love story and the need for individual and collective remembrance.', 'popularity': 7.504, 'poster_path': '/3AufhG0Lej87784i3m1w97jnGCl.jpg', 'release_date': '2024-06-05', 'title': 'Nelly & Nadine', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': None, 'genre_ids': [18], 'id': 362690, 'original_language': 'it', 'original_title': 'Nelly, la domatrice', 'overview': 'A melodrama about a female lion tamer who has an extramarital relationship with a distinguished gentleman, and then moves in with him. When she later comes to regret her actions, her husband has already died of sorrow.', 'popularity': 0.241, 'poster_path': '/lRfwlLY2g9vKX3yILmFYq3JYYYJ.jpg', 'release_date': '1912-08-04', 'title': 'Nelly, the Tamer', 'video': False, 'vote_average': 6.0, 'vote_count': 3}, {'adult': False, 'backdrop_path': None, 'genre_ids': [35], 'id ...
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# Movie 'Nelly & Nadine' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/1dtc6cfrMcJFeaiMPHCGWm6zU0N.jpg', 'genre_ids': [18, 10749], 'id': 814338, 'original_language': 'en', 'original_title': "Lady Chatterley's Lover", 'overview': "Unhappily married aristocrat Lady Chatterley begins a torrid affair — and falls deeply in love — with the gamekeeper on her husband's country estate.", 'popularity': 30.633, 'poster_path': '/aSgl2DxPG3DuQXoaHr500KeULmT.jpg', 'release_date': '2022-11-22', 'title': "Lady Chatterley's Lover", 'video': False, 'vote_average': 6.628, 'vote_count': 393}, {'adult': False, 'backdrop_path': '/dqtxr4jRVTcCCMEgOusTKUb2Iul.jpg', 'genre_ids': [18, 10749], 'id': 132284, 'original_language': 'fr', 'original_title': "L'Amant de Lady Chatterley", 'overview': 'Based on D. H. Lawrence’s 1928 novel of the same name, Lady Chatterley’s Lover stars Danielle Darrieux, Leo Genn, and Erno Crisa in this controversial tale of adultery! After her husband is paralyzed from fighting in WWI, Lady Chatterley feels a loss of intimacy between her husband and herself, and decides to have an affair with the gamekeeper, a man of a lower class.', 'popularity': 8.217, 'poster_path': '/gr8qhgfxKhfG43BRBkEiGSzybL3.jpg', 'release_date': '1955-12-07', 'title': "Lady Chatterley's Lover", 'video': False, 'vote_average': 5.9, 'vote_count': 13}, {'adult': False, 'backdrop_path': '/oECcLf9aTCALv4DGogU0fVZEGgO.jpg', 'genre_ids': [18, 10749], 'id': 35685, 'original_language': 'en', 'original_title': "Lady Chatterley's Lover", 'overview': "After a crippling injury leaves her husband impotent, Lady Chatterly is torn between her love for her husband and her physical desires. With her husband's consent, she seeks out other means of fulfilling her needs.", 'popularity': 16.419, 'poster_path': '/3H58M1rUGO9AOve8GR0svRGmjau.jpg', 'release_date': '1981-06-29', 'title': "Lady Chatterley's Lover", 'video': False, 'vote_average': 5.421, 'vote_count': 76}, {'adult': False, 'backdrop_path': '/txg43Ozkc4X1YGWlmijkipb1Ojq.jpg', 'genre_ids': [10749, 18], 'id': 354743, 'original_language': 'en', 'original_title': "Lady Chatterley's Lover", 'overview': 'An early-20th-century tale of love across class boundaries which tells the legendary and romantic story of Lady Chatterley’s affair with her gamekeeper. Jed Mercurio’s adaptation of DH Lawrence’s classic.', 'popularity': 14.85, 'poster_path': '/6RwYNmcMfsTmOtnNm5PC6LNuy0K.jpg', 'release_date': '2015-09-06', 'title': "Lady Chatterley's Lover", 'video': False, 'vote_average': 6.339, 'vote_count': 115}, {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 1245507, 'original_language': 'en', 'original_title': "Lady Chatterley's Lover", 'overview': 'Adapted from the controversial literary classic by D.H. Lawrence, Lady Chatterley’s Lover is a sweeping, romantic musical with a score by John Robinson and a book by Phil Willmott that played the West End in the summer of 2021. Georgia Lennon stars as Lady Chatterley, an upper-class wife whose love affair with a working-class man prompts her to consider what it means to have a life well-lived.', 'popularity': 0.355, 'poster_path': '/1XAZS89FgtRa7IksdWIhtVnTndj.jpg', 'release_date': '', 'title': "Lady Chatterley's Lover", 'video': False, 'vote_average': 0.0, 'vote_count': 0}], 'total_pages': 1, 'total_results': 5}
# Movie 'Lady Chatterley’s Lover' found and added to the list.
# Movie 'Lady Chatterley’s Lover' found and added to the list.
# Movie 'Lady Chatterley’s Lover' found and added to the list.
# Movie 'Lady Chatterley’s Lover' found and added to the list.
# Movie 'Lady Chatterley’s Lover' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': None, 'genre_ids': [10770, 18], 'id': 1035923, 'original_language': 'en', 'original_title': 'The Sound of Christmas', 'overview': 'A woman facing eviction just before Christmas who must navigate budding romantic feelings for a handsome billionaire when she takes a job nannying for his two children right before Christmas.', 'popularity': 1.173, 'poster_path': '/1Ci8MMMIFzUlDhVWKpzlBQacMLu.jpg', 'release_date': '2022-11-24', 'title': 'The Sound of Christmas', 'video': False, 'vote_average': 8.0, 'vote_count': 4}, {'adult': False, 'backdrop_path': '/kgGzNN0OVn3epoEwQbxnG7ixoPB.jpg', 'genre_ids': [10751], 'id': 1213194, 'original_language': 'en', 'original_title': 'The Wiggles: The Sound of Christmas', 'overview': "Can you hear the sleigh bells jingling? It's The Sound of Christmas! Join The Wiggles and their friends for the most joyous time of the year as they sing and dance along to over 20 festive songs, including many wiggly favourites. There's so much fun to be had in Wiggle Town, from a party on the Goodship Feathersword, to baking a Christmas cake or dancing ballet with Dorothy. Even the great big man in red, Santa Claus, makes a special visit with his prancing reindeer and the most talented elves. So, hang your Christmas stocking, decorate the Christmas tree and, of course, put on your dancing shoes, it's time for a wiggly Christmas!", 'popularity': 0.974, 'poster_path': '/32UTgfRLA4t800M8sNAhaF6AHGo.jpg', 'release_date': '2023-11-24', 'title': 'The Wiggles: The Sound of Christmas', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/uv0HsELMjUTHUKDa7xZibS6FR2W.jpg', 'genre_ids': [10402, 10751, 10770], 'id': 537105, 'original_language': 'en', 'original_title': 'Julie Andrews: The Sound of Christmas', 'overview': 'Julie Andrews joins John Denver, Placido Domingo, and The King\'s Singers for a Christmas journey through time in the city of Salzburg, Austria. Written and sang with many references to "Sound", the journey takes individuals to the many filming locations and haunts that are personal to the cast with music interludes along the way.', 'popularity': 0.825, 'poster_path': '/x91puliYv6575L7yuk5NBXSE6Bn.jpg', 'release_date': '1987-12-16', 'title': 'Julie Andrews: The Sound of Christmas', 'video': False, 'vote_average': 5.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/mr7y8MszBncf8GcMXONpqEjnE0J.jpg', 'genre_ids': [10770, 18], 'id': 423891, 'original_language': 'en', 'original_title': 'Sound of Christmas', 'overview': 'Lizzie is a young piano teacher working at a music school while trying to save enough money for a Steinway piano. The school is gearing up for their major Christmas fundraiser and she has committed much of her time to plan the event. One afternoon, she meets Brad who takes an interest in her playing and asks if she will teach his uninterested teenage daughter. She begins to break through to the young girl, and sparks begin to fly with Brad, but she is shocked to find out that his interest is not solely in her playing, but in the property that houses the music school. She sets out to save the school and the event, but can she work things out with Brad?', 'popularity': 4.664, 'poster_path': '/8NZrtqOfHb5f29WI5ycOk90Ivuk.jpg', 'release_date': '2016-12-11', 'title': 'Sound of Christmas', 'video': False, 'vote_average': 6.4, 'vote_count': 36}], 'total_pages': 1, 'total_results': 4}
# Movie 'The Sound of Christmas' found and added to the list.
# Movie 'The Sound of Christmas' found and added to the list.
# Movie 'The Sound of Christmas' found and added to the list.
# Movie 'The Sound of Christmas' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/lLaeFLQNsZ11zG3LTSczD3YNLad.jpg', 'genre_ids': [18], 'id': 837938, 'original_language': 'en', 'original_title': 'The Inspection', 'overview': 'Ellis French is a young, gay Black man, rejected by his mother and with few options for his future, decides to join the Marines, doing whatever it takes to succeed in a system that would cast him aside. But even as he battles deep-seated prejudice and the grueling routines of basic training, he finds unexpected camaraderie, strength, and support in this new community, giving him a hard-earned sense of belonging that will shape his identity and forever change his life.', 'popularity': 26.393, 'poster_path': '/pvx7TwLXVDKD4jbDeAQ7w459zIY.jpg', 'release_date': '2022-11-18', 'title': 'The Inspection', 'video': False, 'vote_average': 6.179, 'vote_count': 56}, {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 1298401, 'original_language': 'en', 'original_title': 'The Inspection', 'overview': '5 housemates frantically clean their house for a last minute inspection until something goes terribly wrong', 'popularity': 0.01, 'poster_path': '/1bvO6wvfVPOMKG7YFkIwHkYOFro.jpg', 'release_date': '', 'title': 'The Inspection', 'video': True, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/jV8odkNFO12JBt8V3t33B0HvamW.jpg', 'genre_ids': [18], 'id': 877282, 'original_language': 'fr', 'original_title': "L'inspection", 'overview': 'The Inspection is a mighty film without (luckily) any morality in the end — it is a story about what can and what cannot be told to children. A school teacher receives a visit from an educational inspector, who is trying to coherently react to the parents’ complaints. It turns out she spends too much time telling children about the horrible events of the 20th century, in particular about the Holocaust — all in contradiction to the logically drawn school curriculum. She is deeply convinced that while one cannot talk too much about the genocide of the European Jews, it is way too easy not to say enough, not to warn and not to explain.', 'popularity': 8.162, 'poster_path': '/56QbRfTfh8QplmBseODyJXSSgPh.jpg', 'release_date': '2021-09-03', 'title': 'The Inspection', 'video': False, 'vote_average': 7.0, 'vote_count': 2}, {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 919461, 'original_language': 'en', 'original_title': 'The General Inspection of the Average Parade Float', 'overview': "Carl Vinnaman runs a small parade float company in his home town and he got contracted to build the Christmas parade float with his team! Somehow though, Carl messed up the dates and the day that the inspector is coming by to check it out the float isn't even close to being done! Will the team at Parade Float Extravaganza be able to get their float in the parade or will Harriet, the inspector, shut down their business?", 'popularity': 0.001, 'poster_path': None, 'release_date': '', 'title': 'The General Inspection of the Average Parade Float', 'video': True, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/oMsoN3RsJEjxOWcImvwTffEnkMd.jpg', 'genre_ids': [16, 10751, 35, 9648], 'id': 987750, 'original_language': 'es', 'original_title': 'Inspector Sun y la maldición de la viuda negra', 'overview': 'After being put on indefinite leave by his chief of police uncle, the highly intelligent and arrogant huntsman spider Inspector Sun boards a San Francisco bound seaplane. Joined by an intrepid young fan, Sun is pulled into a murder case where the turnout could affect both the insect and human worlds.', 'popularity': 16.541, 'poster_path': '/zUYleUhOpEew8wdcusS0eGytZ6T.jpg', 'release_date': '2022-12-28', 'title': 'Inspector Sun and the Curse of the Black Widow', 'video': False, 'vote_average': 6.7, 'vote_count': 139}, {'adult': False, 'backdrop_path': '/cojOMQvTwcPTSUc0BnRZqfKU34y.jpg', 'genre_ids': [878, 28, 80, 16], 'id': 655431, 'original_language': 'ja', 'original_title': ' ...
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# Movie 'The Inspection' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/8sPxa4sdRvjgRG3GgkO8RQxUR9P.jpg', 'genre_ids': [18, 27, 10749], 'id': 791177, 'original_language': 'it', 'original_title': 'Bones and All', 'overview': 'Abandoned by her father, a young woman embarks on a thousand-mile odyssey through the backroads of America where she meets a disenfranchised drifter. But despite their best efforts, all roads lead back to their terrifying pasts and to a final stand that will determine whether their love can survive their otherness.', 'popularity': 30.307, 'poster_path': '/ayfr4iL0jVV9mquN7SKvjOidvRH.jpg', 'release_date': '2022-11-18', 'title': 'Bones and All', 'video': False, 'vote_average': 7.068, 'vote_count': 1252}], 'total_pages': 1, 'total_results': 1}
# Movie 'Bones and All' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/s5MLcxbdFqvIzTLNLU5yQFFYALR.jpg', 'genre_ids': [18, 10749], 'id': 744114, 'original_language': 'en', 'original_title': 'My Policeman', 'overview': 'In the late 1990s, the arrival of elderly invalid Patrick into Marion and Tom’s home triggers the exploration of seismic events from 40 years previous: the passionate relationship between Tom and Patrick at a time when homosexuality was illegal.', 'popularity': 24.341, 'poster_path': '/wdbiMjXd4CxPfCx4r4Jfy8cGec0.jpg', 'release_date': '2022-10-20', 'title': 'My Policeman', 'video': False, 'vote_average': 7.726, 'vote_count': 639}], 'total_pages': 1, 'total_results': 1}
# Movie 'My Policeman' found and added to the list.
# ...
# Movie 'Lost in Paris' found and added to the list.
# Movie 'Lost in Paris' found and added to the list.
# Movie 'Lost in Paris' found and added to the list.
# Movie 'Lost in Paris' found and added to the list.
# Movie 'Lost in Paris' found and added to the list.
# Movie 'Lost in Paris' found and added to the list.
# Movie 'Lost in Paris' found and added to the list.
# Movie 'Lost in Paris' found and added to the list.
# Movie 'Lost in Paris' found and added to the list.
# Movie 'Lost in Paris' found and added to the list.
# {'page': 1, 'results': [], 'total_pages': 1, 'total_results': 0}
# {'page': 1, 'results': [], 'total_pages': 1, 'total_results': 0}
# {'page': 1, 'results': [], 'total_pages': 1, 'total_results': 0}
# {'page': 1, 'results': [], 'total_pages': 1, 'total_results': 0}
# {'page': 1, 'results': [], 'total_pages': 1, 'total_results': 0}
# {'page': 1, 'results': [], 'total_pages': 1, 'total_results': 0}
# {'page': 1, 'results': [], 'total_pages': 1, 'total_results': 0}
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/eTovTpBgekkg9HZ5wGXUiiWys9M.jpg', 'genre_ids': [18, 10749], 'id': 381015, 'original_language': 'en', 'original_title': 'The Other Half', 'overview': 'A grief-stricken man and a bipolar woman fall in love and attempt to forge a simple life together.', 'popularity': 5.6, 'poster_path': '/jZ32u1vf7lb25rpuPl6LWoZAUvD.jpg', 'release_date': '2016-12-02', 'title': 'The Other Half', 'video': False, 'vote_average': 6.3, 'vote_count': 24}, {'adult': False, 'backdrop_path': None, 'genre_ids': [18, 35, 10749], 'id': 38820, 'original_language': 'en', 'original_title': 'The Other Half', 'overview': 'When English Mark surprises his American bride Holly with her dream honeymoon to Portugal she cant believe her luck. Mark goes to great trouble to organise everything for her. They arrive in Portugal to discover that the country is hosting a major international soccer tournament and that the English national team is playing! Whats more, the England team, and their raucous fans, seem to follow them everywhere. Soccer-loving Mark claims innocence - a complete coincidence - after all, what kind of man would lie to his new wife just to watch England play in a tournament?', 'popularity': 2.719, 'poster_path': '/ldj2Fz4LBQ5npo0Q8jIewvJFmWa.jpg', 'release_date': '2006-05-15', 'title': 'The Other Half', 'video': False, 'vote_average': 6.7, 'vote_count': 13}, {'adult': False, 'backdrop_path': None, 'genre_ids': [18], 'id': 346583, 'original_language': 'it', 'original_title': "L'altra metà", 'overview': 'It tells the story of an elderly woman, confined in a nursing home because of her poor health. Her daughters do not want to take her to the wedding of her granddaughter. The woman, with the complicity of a nurse, escaped from there, determined at all costs to attend the wedding of her granddaughter.', 'popularity': 0.862, 'poster_path': '/xv17r0AdcrGTXvJO7pIQkLA9V5M.jpg', 'release_date': '2009-12-03', 'title': 'The Other Half', 'video': False, 'vote_average': 6.4, 'vote_count': 4}, {'adult': False, 'backdrop_path': '/bPfsgKivPQ3QmENuhpe9RFM94UJ.jpg', 'genre_ids': [99], 'id': 948030, 'original_language': 'el', 'original_title': 'The Other Half', 'overview': 'For 15 years, a photojournalist bears witness to migrant journeys across the dark crossings of European borders. His camera delves into inaccessible places, documenting the stories of people who push human boundaries, to reveal how the Other Half lives.', 'popularity': 0.041, 'poster_path': '/cVNt7edDJjZs4MHdezaGE15aKs2.jpg', 'release_date': '2022-11-08', 'title': 'The Other Half', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': None, 'genre_ids': [18], 'id': 944875, 'original_language': 'en', 'original_title': 'The Other Half', 'overview': 'A laborer, who lived with his family in a New York tenement, was in better financial condition than most of his associates. Misfortune came upon the man, however, and as the result of an accident, his arm was amputated. When he recovered and applied for his old position, he was turned down because he was physically unable to perform the work.', 'popularity': 0.315, 'poster_path': None, 'release_date': '1912-12-17', 'title': 'The Other Half', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 1034260, 'original_language': 'en', 'original_title': 'The other half', 'overview': 'The story is told across nine screens. After yet another misunderstanding with her girlfriend, a girl writes her thoughts in her diary: she tells what it means for her to love, accept yourself and face your fears, while remembering all those moments of carefree and suffering that she spent with her girlfriend.', 'popularity': 0.001, 'poster_path': None, 'release_date': '', 'title': 'The other half', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/xc1CJfacOuDf3jm9WZuXjDaI48T.jpg', 'genre_ ...
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# Movie 'The Other Half' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/5kmoreEiqaU0JoE8GZmLwLvAsJq.jpg', 'genre_ids': [10749, 18, 10752], 'id': 433356, 'original_language': 'en', 'original_title': 'The Ottoman Lieutenant', 'overview': 'Lillie, a determined American woman, ventures overseas to join Dr. Jude at a remote medical mission in the Ottoman Empire (now Turkey). However, Lillie soon finds herself at odds with Jude and the mission’s founder, Woodruff, when she falls for the titular military man, Ismail, just as the war is about to erupt.', 'popularity': 18.209, 'poster_path': '/c5E8KTDuGNdF4Lmv3OhsQ0W1zPw.jpg', 'release_date': '2017-03-10', 'title': 'The Ottoman Lieutenant', 'video': False, 'vote_average': 6.169, 'vote_count': 246}], 'total_pages': 1, 'total_results': 1}
# Movie 'The Ottoman Lieutenant' found and added to the list.
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/9JNsAIFMu4o37AgnU1JVtR6AWsK.jpg', 'genre_ids': [10749, 28, 18], 'id': 1248795, 'original_language': 'tr', 'original_title': 'Romantik Hırsız', 'overview': 'After learning that the art thief she has been chasing is her ex-lover, an officer working for Interpol concocts a plan to catch him red-handed.', 'popularity': 81.97, 'poster_path': '/niVtvS9Kf8G1VDPSqurqHkaSSwm.jpg', 'release_date': '2024-03-13', 'title': 'Art of Love', 'video': False, 'vote_average': 6.5, 'vote_count': 110}, {'adult': False, 'backdrop_path': '/pzvnnpJmCtSZMw44WYVEqldhn17.jpg', 'genre_ids': [35, 10749], 'id': 1143319, 'original_language': 'en', 'original_title': 'Puppy Love', 'overview': 'After a disastrous first date, wild-child Nicole and socially-anxious Max vow to lose each other’s numbers until they learn that their dogs found a love match, and now puppies are on the way! The hilariously mismatched Nicole and Max are forced to become responsible co-parents, but may end up finding love themselves.', 'popularity': 100.236, 'poster_path': '/oTc03izWZ9UdD3y0HegVV2M0s0J.jpg', 'release_date': '2023-08-22', 'title': 'Puppy Love', 'video': False, 'vote_average': 7.138, 'vote_count': 167}, {'adult': False, 'backdrop_path': '/tLAzri58mu0nFurXI10M6eYm0LD.jpg', 'genre_ids': [18, 10749], 'id': 173129, 'original_language': 'zh', 'original_title': '金瓶風月', 'overview': 'A corrupt local official, Xi Men Qing, who lusts after women and money, pursues his brother\'s young wife, Lee Ping Er. Ping finds Men attractive, and under her drunken husband\'s nose, she and Men work their way through the illustrations of a pillow book, the "Golden Lotus." Men pursues the same feat with his fourth concubine, Pan Jing Lien, who lives in the compound next to Ping. Jing\'s jealousy compounds a tale of humiliation, childbirth, death, and depravity. Does karma or enlightenment await anyone?', 'popularity': 109.333, 'poster_path': '/nA1WbYl6Sllm71g8koNXhjWbMOc.jpg', 'release_date': '1991-05-09', 'title': 'The Golden Lotus: Love and Desire', 'video': False, 'vote_average': 5.947, 'vote_count': 19}, {'adult': False, 'backdrop_path': '/jsoz1HlxczSuTx0mDl2h0lxy36l.jpg', 'genre_ids': [14, 28, 35], 'id': 616037, 'original_language': 'en', 'original_title': 'Thor: Love and Thunder', 'overview': 'After his retirement is interrupted by Gorr the God Butcher, a galactic killer who seeks the extinction of the gods, Thor Odinson enlists the help of King Valkyrie, Korg, and ex-girlfriend Jane Foster, who now wields Mjolnir as the Mighty Thor. Together they embark upon a harrowing cosmic adventure to uncover the mystery of the God Butcher’s vengeance and stop him before it’s too late.', 'popularity': 141.287, 'poster_path': '/pIkRyD18kl4FhoCNQuWxWu5cBLM.jpg', 'release_date': '2022-07-06', 'title': 'Thor: Love and Thunder', 'video': False, 'vote_average': 6.464, 'vote_count': 7208}, {'adult': False, 'backdrop_path': '/j1bOCozOQOxJpk0iAQbJDS2w8OJ.jpg', 'genre_ids': [18, 10749], 'id': 1081676, 'original_language': 'pl', 'original_title': 'Znachor', 'overview': "A once-respected surgeon who's lost his family and his memory gets a chance at redemption when he reconnects with someone from his forgotten past.", 'popularity': 35.227, 'poster_path': '/8mHfCmc2dt6wk2DNc0NXlYXOzVj.jpg', 'release_date': '2023-09-27', 'title': 'Forgotten Love', 'video': False, 'vote_average': 7.96, 'vote_count': 236}, {'adult': False, 'backdrop_path': '/oMiKHO3H5RixfLsiU5Vumhlp5sj.jpg', 'genre_ids': [80, 10749, 53], 'id': 948549, 'original_language': 'en', 'original_title': 'Love Lies Bleeding', 'overview': 'Reclusive gym manager Lou falls hard for Jackie, an ambitious bodybuilder headed through town to Las Vegas in pursuit of her dream. But their love ignites violence, pulling them deep into the web of Lou’s criminal family.', 'popularity': 159.712, 'poster_path': '/p7jyFWiLyHPttqYBFAlLJwtYTYH.jpg', 'release_date': '2024-03-08', 'title': 'Love Lies Bleeding', 'video': Fal ...
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# Movie 'Love & Taxes' found and added to the list.
# {'page': 1, 'results': [], 'total_pages': 1, 'total_results': 0}
# Going to sleep
# {'page': 1, 'results': [], 'total_pages': 1, 'total_results': 0}

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list[:5], indent=4))
# Out:
# [
#     465914,
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": null,
#         "original_language": "es",
#         "homepage": null,
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 5.33,
#         "runtime": null,
#         "revenue": null,
#         "release_date": "2021-10-07",
#         "vote_average": 3.0,
#         "vote_count": 4,
#         "genres": [],
#         "spoken_languages": [],
#         "production_countries": []
#     },
#     465914,
#     {
#         "title": "You Can Live Forever",
#         "original_title": "You Can Live Forever",
#         "budget": null,
#         "original_language": "en",
#         "homepage": null,
#         "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#         "popularity": 36.875,
#         "runtime": null,
#         "revenue": null,
#         "release_date": "2023-03-24",
#         "vote_average": 6.611,
#         "vote_count": 36,
#         "genres": [],
#         "spoken_languages": [],
#         "production_countries": []
#     },
#     465914
# ]

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)

# %%
json_str = json.dumps(tmdb_movies_list)
data = json.loads(json_str)
tmdb_df = pd.json_normalize(data, sep='-')
tmdb_df
# Out:
#                        title        original_title  budget original_language  \
# 0                        NaN                   NaN     NaN               NaN
# 1     The Attachment Diaries              El apego     NaN                es
# 2                        NaN                   NaN     NaN               NaN
# 3       You Can Live Forever  You Can Live Forever     NaN                en
# 4                        NaN                   NaN     NaN               NaN
# ...                      ...                   ...     ...               ...
# 2655            Love & Taxes                화려한 외출     NaN                ko
# 2656                     NaN                   NaN     NaN               NaN
# 2657            Love & Taxes              유열의 음악앨범     NaN                ko
# 2658                     NaN                   NaN     NaN               NaN
# 2659            Love & Taxes    Love & Other Drugs     NaN                en
#
#       homepage                                           overview  popularity  \
# 0          NaN                                                NaN         NaN
# 1          NaN  Argentina, 1970s. A desperate young woman goes...       5.330
# 2          NaN                                                NaN         NaN
# 3          NaN  When Jaime, a gay teenager, is sent to live in...      36.875
# 4          NaN                                                NaN         NaN
# ...        ...                                                ...         ...
# 2655       NaN  Korea's most popular song writer Hee-soo runs ...      50.280
# 2656       NaN                                                NaN         NaN
# 2657       NaN  During the 1990s, hardworking Mi-soo and optim...      27.398
# 2658       NaN                                                NaN         NaN
# 2659       NaN  Maggie is an alluring free spirit who won't le...      60.522
#
#       runtime  revenue release_date  vote_average  vote_count genres  \
# 0         NaN      NaN          NaN           NaN         NaN    NaN
# 1         NaN      NaN   2021-10-07         3.000         4.0     []
# 2         NaN      NaN          NaN           NaN         NaN    NaN
# 3         NaN      NaN   2023-03-24         6.611        36.0     []
# 4         NaN      NaN          NaN           NaN         NaN    NaN
# ...       ...      ...          ...           ...         ...    ...
# 2655      NaN      NaN   2013-12-05         6.900        33.0     []
# 2656      NaN      NaN          NaN           NaN         NaN    NaN
# 2657      NaN      NaN   2019-08-28         7.847       249.0     []
# 2658      NaN      NaN          NaN           NaN         NaN    NaN
# 2659      NaN      NaN   2010-11-04         7.050      4975.0     []
#
#      spoken_languages production_countries
# 0                 NaN                  NaN
# 1                  []                   []
# 2                 NaN                  NaN
# 3                  []                   []
# 4                 NaN                  NaN
# ...               ...                  ...
# 2655               []                   []
# 2656              NaN                  NaN
# 2657               []                   []
# 2658              NaN                  NaN
# 2659               []                   []
#
# [2660 rows x 15 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(df_reviews, tmdb_df, on="title", how="inner")

# %%
merged_df
# Out:
#                                                 web_url  \
# 0     https://www.nytimes.com/2023/05/25/movies/the-...
# 1     https://www.nytimes.com/2023/05/04/movies/you-...
# 2     https://www.nytimes.com/2023/04/21/movies/a-to...
# 3     https://www.nytimes.com/2023/04/20/movies/othe...
# 4     https://www.nytimes.com/2023/04/20/movies/othe...
# ...                                                 ...
# 1325  https://www.nytimes.com/2017/03/02/movies/love...
# 1326  https://www.nytimes.com/2017/03/02/movies/love...
# 1327  https://www.nytimes.com/2017/03/02/movies/love...
# 1328  https://www.nytimes.com/2017/03/02/movies/love...
# 1329  https://www.nytimes.com/2017/03/02/movies/love...
#
#                                                 snippet              source  \
# 0     A gynecologist and her patient form a horrifyi...  The New York Times
# 1     Religion comes between two girls falling in lo...  The New York Times
# 2     Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 3     A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 4     A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ...                                                 ...                 ...
# 1325  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 1326  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 1327  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 1328  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 1329  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
#
#                                                keywords  \
# 0     subject: Movies;creative_works: The Attachment...
# 1     subject: Movies;creative_works: You Can Live F...
# 2     subject: Movies;creative_works: A Tourist's Gu...
# 3     subject: Movies;persons: Zlotowski, Rebecca;cr...
# 4     subject: Movies;persons: Zlotowski, Rebecca;cr...
# ...                                                 ...
# 1325  creative_works: Love & Taxes (Movie);persons: ...
# 1326  creative_works: Love & Taxes (Movie);persons: ...
# 1327  creative_works: Love & Taxes (Movie);persons: ...
# 1328  creative_works: Love & Taxes (Movie);persons: ...
# 1329  creative_works: Love & Taxes (Movie);persons: ...
#
#                       pub_date  word_count  \
# 0     2023-05-25T11:00:03+0000         295
# 1     2023-05-04T11:00:08+0000         294
# 2     2023-04-21T07:03:25+0000         276
# 3     2023-04-20T15:35:13+0000         801
# 4     2023-04-20T15:35:13+0000         801
# ...                        ...         ...
# 1325  2017-03-02T21:44:18+0000         246
# 1326  2017-03-02T21:44:18+0000         246
# 1327  2017-03-02T21:44:18+0000         246
# 1328  2017-03-02T21:44:18+0000         246
# 1329  2017-03-02T21:44:18+0000         246
#
#                                           headline.main headline.kicker  \
# 0           ‘The Attachment Diaries’ Review: Love, Sick            None
# 1     ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2     ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 3        ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 4        ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ...                                                 ...             ...
# 1325  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 1326  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 1327  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 1328  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 1329  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
#
#      headline.content_kicker                 headline.print_headline  ...  \
# 0                       None                  The Attachment Diaries  ...
# 1                       None                    You Can Live Forever  ...
# 2                       None              A Tourist’s  Guide to Love  ...
# 3                       None  Intoxicating Love With a Sobering Turn  ...
# 4                       None  Intoxicating Love With a Sobering Turn  ...
# ...                      ...                                     ...  ...
# 1325                    None        It’s Inevitable, Mirth and Taxes  ...
# 1326                    None        It’s Inevitable, Mirth and Taxes  ...
# 1327                    None        It’s Inevitable, Mirth and Taxes  ...
# 1328                    None        It’s Inevitable, Mirth and Taxes  ...
# 1329                    None        It’s Inevitable, Mirth and Taxes  ...
#
#                                                overview popularity runtime  \
# 0     Argentina, 1970s. A desperate young woman goes...      5.330     NaN
# 1     When Jaime, a gay teenager, is sent to live in...     36.875     NaN
# 2     After an unexpected break up, a travel executi...     16.426     NaN
# 3     Rachel loves her life, her students, her frien...      9.846     NaN
# 4     The sympathetic farmers couple, Mads and Katri...      0.234     NaN
# ...                                                 ...        ...     ...
# 1325  Rei is a college student in the midst of findi...      9.447     NaN
# 1326  In Hong Kong of 1962, Mrs. Chan and Mr. Chow, ...     32.917     NaN
# 1327  Korea's most popular song writer Hee-soo runs ...     50.280     NaN
# 1328  During the 1990s, hardworking Mi-soo and optim...     27.398     NaN
# 1329  Maggie is an alluring free spirit who won't le...     60.522     NaN
#
#      revenue release_date vote_average vote_count genres  spoken_languages  \
# 0        NaN   2021-10-07        3.000        4.0     []                []
# 1        NaN   2023-03-24        6.611       36.0     []                []
# 2        NaN   2023-04-21        6.291      160.0     []                []
# 3        NaN   2022-09-21        6.823      189.0     []                []
# 4        NaN   1958-01-01        4.000        2.0     []                []
# ...      ...          ...          ...        ...    ...               ...
# 1325     NaN   2019-02-02        5.800        5.0     []                []
# 1326     NaN   2000-09-29        8.109     2577.0     []                []
# 1327     NaN   2013-12-05        6.900       33.0     []                []
# 1328     NaN   2019-08-28        7.847      249.0     []                []
# 1329     NaN   2010-11-04        7.050     4975.0     []                []
#
#      production_countries
# 0                      []
# 1                      []
# 2                      []
# 3                      []
# 4                      []
# ...                   ...
# 1325                   []
# 1326                   []
# 1327                   []
# 1328                   []
# 1329                   []
#
# [1330 rows x 31 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["genres", "spoken_languages", "production_countries"]
characters_to_remove = ['[', ']', '.']

# Create a list of characters to remove


# Loop through the list of columns to fix
for column in columns_to_fix:
    merged_df[column] = merged_df[column].astype(str)
    for char in characters_to_remove:
        merged_df[column] = merged_df[column].str.replace(char, "")

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/21/movies/a-to...
# 3  https://www.nytimes.com/2023/04/20/movies/othe...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 3  A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: You Can Live F...
# 2  subject: Movies;creative_works: A Tourist's Gu...
# 3  subject: Movies;persons: Zlotowski, Rebecca;cr...
# 4  subject: Movies;persons: Zlotowski, Rebecca;cr...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T11:00:08+0000         294
# 2  2023-04-21T07:03:25+0000         276
# 3  2023-04-20T15:35:13+0000         801
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 3     ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  ...  \
# 0                    None                  The Attachment Diaries  ...
# 1                    None                    You Can Live Forever  ...
# 2                    None              A Tourist’s  Guide to Love  ...
# 3                    None  Intoxicating Love With a Sobering Turn  ...
# 4                    None  Intoxicating Love With a Sobering Turn  ...
#
#                                             overview popularity runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...      5.330     NaN
# 1  When Jaime, a gay teenager, is sent to live in...     36.875     NaN
# 2  After an unexpected break up, a travel executi...     16.426     NaN
# 3  Rachel loves her life, her students, her frien...      9.846     NaN
# 4  The sympathetic farmers couple, Mads and Katri...      0.234     NaN
#
#   revenue release_date vote_average vote_count genres  spoken_languages  \
# 0     NaN   2021-10-07        3.000        4.0
# 1     NaN   2023-03-24        6.611       36.0
# 2     NaN   2023-04-21        6.291      160.0
# 3     NaN   2022-09-21        6.823      189.0
# 4     NaN   1958-01-01        4.000        2.0
#
#   production_countries
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 31 columns]

# %%
# Drop "byline.person" column
merged_df = merged_df.drop(columns=["byline.person"])

# %%
# Delete duplicate rows and reset index
merged_df = merged_df.drop_duplicates().reset_index(drop=True)

# %%
# Export data to CSV without the index
merged_df.to_csv("merged_movie_data.csv", index=False)

# %%
#merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/21/movies/a-to...
# 3  https://www.nytimes.com/2023/04/20/movies/othe...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 3  A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: You Can Live F...
# 2  subject: Movies;creative_works: A Tourist's Gu...
# 3  subject: Movies;persons: Zlotowski, Rebecca;cr...
# 4  subject: Movies;persons: Zlotowski, Rebecca;cr...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T11:00:08+0000         294
# 2  2023-04-21T07:03:25+0000         276
# 3  2023-04-20T15:35:13+0000         801
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 3     ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  ...  \
# 0                    None                  The Attachment Diaries  ...
# 1                    None                    You Can Live Forever  ...
# 2                    None              A Tourist’s  Guide to Love  ...
# 3                    None  Intoxicating Love With a Sobering Turn  ...
# 4                    None  Intoxicating Love With a Sobering Turn  ...
#
#                                             overview popularity runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...      5.330     NaN
# 1  When Jaime, a gay teenager, is sent to live in...     36.875     NaN
# 2  After an unexpected break up, a travel executi...     16.426     NaN
# 3  Rachel loves her life, her students, her frien...      9.846     NaN
# 4  The sympathetic farmers couple, Mads and Katri...      0.234     NaN
#
#   revenue release_date vote_average vote_count  genres spoken_languages  \
# 0     NaN   2021-10-07        3.000        4.0
# 1     NaN   2023-03-24        6.611       36.0
# 2     NaN   2023-04-21        6.291      160.0
# 3     NaN   2022-09-21        6.823      189.0
# 4     NaN   1958-01-01        4.000        2.0
#
#    production_countries
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 30 columns]
